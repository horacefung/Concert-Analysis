# %% [markdown]
# # Backend Database (Part 4: Songkick)
#
# The foundation of our backend is to have an extensive list of artist and information relevant to them. We will use X different APIs to collect various information:
#
# 1. lastfm API to gather a long list of artists, mainly those popular in the US.
# 2. SeatGeek API to gather data on upcoming concerts, particularly ticket pricing and concert size.
# 3. Scrape SeatGeek website for capacity information on concert venues.
# 4. **Songkick API to retrieve data on historical concerts.**
# 5. Scrape Billboard website for recent successful concerts. Includes information like revenue and attendance.

# %%
import requests
import pickle
import MySQLdb as mdb
import sys
from datetime import datetime

# %% [markdown]
# ## Defining a few functions to fetch data

# %% [markdown]
# **(i) Functions to get ids and names used in Songkick's database**

# %%
#Functions that utilize search API
#Use the search query to get a matching id json response | returns a dictionary:
def search_api(sql_name):
    url_id = "http://api.songkick.com/api/3.0/search/artists.json?apikey=<apikey>&query={}".format(sql_name)
    ids = requests.get(url_id).json()
    return ids

#Function to get artist ID | returns integer
def search_id(ids):
    try:
        return ids['resultsPage']['results']['artist'][0]['id']
    except:
        None

#Function to get displayName for searching | returns a string:
def search_displayName(ids):
    try:
        return ids['resultsPage']['results']['artist'][0]['displayName']
    except:
        None

# %% [markdown]
# **(ii) Functions to get past concerts using ids retrieved in (i)**

# %%
#Function to use id gigography API
#Returns a list with useful information:
def get_gigography(artist_id):
    gigography_cleaned = []
    try:
        for i in range(1,6):
            base = "http://api.songkick.com/api/3.0/artists/"
            page = i
            api_key = "apikey"
            url_gig = base + "{}/gigography.json?apikey={}&query&order=desc&page={}".format(artist_id, api_key, page)
            response = requests.get(url_gig).json()
            gigography_result = response['resultsPage']['results']['event']
            gigography_cleaned += gigography_result
        return gigography_cleaned
    except:
        None

# %%
url_gig = "http://api.songkick.com/api/3.0/artists/315398/gigography.json?apikey=<apikey>&query&order=desc&page=2"
a = requests.get(url_gig).json()

# %%
base = "http://api.songkick.com/api/3.0/artists/"
page = '1'
page2 = 2
api_key = "<apikey>"
url_gig = base + "{}/gigography.json?apikey={}&query&order=desc&page={}".format(315398, api_key, page)
response1 = requests.get(url_gig).json()
gigography_result1 = response1['resultsPage']['results']['event']

url_gig2 = base + "{}/gigography.json?apikey={}&query&order=desc&page={}".format(315398, api_key, page2)
response2 = requests.get(url_gig2).json()
gigography_result2 = response2['resultsPage']['results']['event']

# %% [markdown]
# **(iii) Function to get relevant data from the json response in (ii)**

# %%
#Functions to use gigoraphy_result
#Begin with search['resultsPage']['results']['event'] | returns a list of concerts:
def get_details(gigography_result, displayName, artistname):
    empty_list = []
    try:
        for i in range(len(gigography_result)):
            dict1 = {}
            dict1['artist'] = artistname
            dict1['concert'] = gigography_result[i]['displayName']
            dict1['date'] = datetime.strptime(gigography_result[i]['start']['date'], '%Y-%m-%d')
            dict1['city'] = gigography_result[i]['location']['city']
            dict1['lat'] = gigography_result[i]['location']['lat']
            dict1['lon'] = gigography_result[i]['location']['lng']
            performance = gigography_result[i]['performance'] #specifies the performance
            for j in range(len(performance)):
                if performance[j]['displayName'] == displayName: #check if each performer is == displayName
                    dict1['role'] = performance[j]['billing'] #returns the one that is equal 
                    empty_list.append(dict1)
        return empty_list
    except:
        None

# %% [markdown]
# # Creating Songkick table and inserting data

# %%
#A function that shifts the list each time
def shift(pickled_list, n):
    return pickled_list[n:] + pickled_list[:n]

# %%
#Open pickled file containing the artist names
fileObject = open("/home/ubuntu/jupyter/Student_Notebooks/Assignments/Project/Crontab/songkick_artist_name_list",'rb') 
old_pickled_list = pickle.load(fileObject)

# %%
#Restricting the search to 20 artists 
list_30 = old_pickled_list[0:30]

# %%
input_list = []
for i in list_30:
    name_artist = search_api(i)
    id_artist = search_id(name_artist)
    displayName = search_displayName(name_artist)
    gigography_result = get_gigography(id_artist)
    details = get_details(gigography_result, displayName, i)
    input_list.append(details)

# %%
input_list = [x for x in input_list if x != None]

# %%
#Connecting to MySQL database
con = mdb.connect(host = 'localhost', 
                  user = 'root',
                  passwd = '<password>', 
                  charset='utf8', use_unicode=True);

# %%
#Create a table for Songkick
cursor = con.cursor()
table_name = 'songkick'

create_table_query = '''CREATE TABLE IF NOT EXISTS {db}.{table} 
                                (artist varchar(250), 
                                concert_date datetime,
                                concert_name varchar(250),
                                role varchar(250),
                                city varchar(250),
                                latitude int,
                                longitude int,
                                PRIMARY KEY(artist, concert_date)
                                )'''.format(db='Project', table=table_name)
cursor.execute(create_table_query)
cursor.close()

# %%
#Insert songkick data
cursor = con.cursor()
table_name = 'songkick'

query_template = '''INSERT IGNORE INTO {db}.{table}(artist, 
                                            concert_date,
                                            concert_name,
                                            role,
                                            city,
                                            latitude,
                                            longitude) 
                                            VALUES (%s, %s, %s, %s, %s, %s, %s)'''.format(db="Project", table=table_name)

cursor = con.cursor()



for data in input_list:
    for i in range(len(data)):
        artist = data[i]['artist']
        concert_date = data[i]['date']
        concert_name = data[i]['concert']
        role = data[i]['role']
        city = data[i]['city']
        latitude = data[i]['lat']
        longitude = data[i]['lon']
        
        query_parameters = (artist, concert_date, concert_name, role, city, latitude, longitude)
        cursor.execute(query_template, query_parameters)

con.commit()
cursor.close()
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'the-beatles-1964-09-16 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'the-beatles-1964-02-11 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'radiohead-2017-06-09 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'radiohead-2016-10-07 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'radiohead-2016-09-30 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'radiohead-2016-08-20 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'radiohead-2016-06-01 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'radiohead-2012-09-20 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'radiohead-2012-07-27 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'radiohead-2012-06-10 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'radiohead-2012-04-17 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'radiohead-2012-03-15 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'radiohead-2009-08-28 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'radiohead-2008-08-13 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'radiohead-2008-08-08 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'radiohead-2008-07-03 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'radiohead-2008-06-20 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'radiohead-2006-08-19 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'coldplay-2016-09-03 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'coldplay-2016-06-12 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'coldplay-2012-09-02 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'coldplay-2012-06-09 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'coldplay-2011-09-23 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'muse-2017-08-25 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'muse-2017-07-06 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'muse-2016-08-19 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'muse-2016-07-14 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'muse-2016-05-12 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'muse-2016-05-06 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'muse-2016-03-15 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'muse-2016-03-13 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'muse-2016-03-12 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'muse-2015-07-09 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'muse-2015-07-03 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'muse-2015-06-25 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'muse-2015-06-12 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'muse-2015-06-04 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'muse-2015-05-29 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'muse-2014-04-05 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'muse-2013-12-13 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'muse-2013-08-10 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'arctic-monkeys-2014-09-05 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'arctic-monkeys-2014-08-30 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'arctic-monkeys-2014-08-22 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'arctic-monkeys-2014-08-16 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'arctic-monkeys-2014-08-08 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'arctic-monkeys-2014-08-01 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'arctic-monkeys-2014-07-12 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'arctic-monkeys-2014-07-11 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'arctic-monkeys-2014-07-10 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'arctic-monkeys-2014-06-07 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'arctic-monkeys-2013-12-13 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'arctic-monkeys-2013-12-12 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'arctic-monkeys-2013-12-06 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'arctic-monkeys-2013-11-21 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'arctic-monkeys-2013-11-20 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'arctic-monkeys-2013-11-18 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'arctic-monkeys-2013-07-18 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'arctic-monkeys-2013-07-16 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'arctic-monkeys-2013-07-15 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'arctic-monkeys-2013-06-21 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'arctic-monkeys-2012-04-22 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'pink-floyd-2005-07-02 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'pink-floyd-1994-08-23 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'pink-floyd-1994-05-29 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'pink-floyd-1993-09-18 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'pink-floyd-1990-06-30 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'pink-floyd-1988-05-28 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'red-hot-chili-peppers-2017-09-21 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'red-hot-chili-peppers-2017-07-13 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'red-hot-chili-peppers-2017-06-28 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'red-hot-chili-peppers-2016-08-26 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'red-hot-chili-peppers-2016-07-22 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'red-hot-chili-peppers-2016-07-06 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'red-hot-chili-peppers-2016-06-03 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'red-hot-chili-peppers-2013-06-08 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'red-hot-chili-peppers-2012-08-25 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'red-hot-chili-peppers-2012-07-05 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'red-hot-chili-peppers-2012-06-30 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'red-hot-chili-peppers-2012-06-28 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'red-hot-chili-peppers-2012-06-26 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'linkin-park-2017-06-23 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'linkin-park-2017-06-11 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'linkin-park-2015-08-31 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'linkin-park-2015-06-23 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'linkin-park-2013-08-10 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'linkin-park-2012-08-28 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'linkin-park-2012-08-14 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'linkin-park-2011-06-30 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'linkin-park-2011-06-25 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'metallica-2017-05-19 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'metallica-2015-08-28 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'metallica-2015-05-29 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'metallica-2014-07-11 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'metallica-2014-07-06 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'metallica-2014-07-04 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'metallica-2014-06-06 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'metallica-2014-06-03 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'metallica-2014-06-01 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'metallica-2014-03-27 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'metallica-2013-08-10 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'metallica-2012-06-08 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'metallica-2012-05-25 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'metallica-2011-07-08 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'metallica-2011-04-23 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'metallica-2010-06-25 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'metallica-2010-06-24 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'metallica-2010-06-22 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'metallica-2010-06-19 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'metallica-2010-06-14 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'metallica-2010-05-14 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'lady-gaga-2015-04-24 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'lady-gaga-2014-08-13 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'lady-gaga-2014-05-12 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'lady-gaga-2012-09-26 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'system-of-a-down-2017-06-20 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'system-of-a-down-2017-06-14 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'system-of-a-down-2017-06-09 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'system-of-a-down-2015-06-19 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'system-of-a-down-2013-08-23 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'system-of-a-down-2013-08-18 00:00:00' for key 'PRIMARY'")
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: Warning: (1062, "Duplicate entry 'system-of-a-down-